# %% [markdown]
# """Full Pipeline Demo (Stages 0-2 with LLM-enabled service).
#
# Flow:
# 1. Stage 0: Project Setup (ProjectContext)
# 2. Approve context
# 3. Stage 1: Problem Framing (ProblemFraming + ConceptModel)
# 4. Approve framing & concept model
# 5. Stage 2: Research Questions (ResearchQuestionSet)
# 6. Display summaries of each artifact
#
# Assumes .env configured with LLM provider (mock or openai via OpenRouter).
# """

# %%
import os
import logging
from dotenv import load_dotenv, find_dotenv

# Force load .env (prints path for verification)
dotenv_path = find_dotenv(usecwd=True)
if not dotenv_path:
    raise FileNotFoundError("`.env` not found. Place it in project root.")
load_dotenv(dotenv_path=dotenv_path)

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# Continue with imports AFTER env is loaded
from src.controller import PipelineController
from src.services import FilePersistenceService, IntelligentModelService
from src.models import (
    ProjectContext, ProblemFraming, ConceptModel,
    ResearchQuestionSet, SearchConceptBlocks, ApprovalStatus
)

RAW_IDEA = (
    """# Search Queries for Scoping Review

**Research Topic:** Domain Shift and Generalization in Deep Learning-Based Crop Disease and Pest Detection

**Research Question:** What is the landscape of research on domain shift and generalization  in deep learning-based crop disease and pest detection? What types of  evidence, methodologies, and gaps exist?"""
)

def approve(controller, project_id, artifact_type, artifact_class, edits=None):
    controller.approve_artifact(
        project_id=project_id,
        artifact_type=artifact_type,
        artifact_class=artifact_class,
        edits=edits or {},
        approval_status=ApprovalStatus.APPROVED
    )

# %%
print("\n=== FULL PIPELINE DEMO (Stages 0-3) ===\n")
model_service = IntelligentModelService()
persistence = FilePersistenceService(base_dir="./data")
controller = PipelineController(model_service=model_service, persistence_service=persistence)

# Stage 0
print("[Stage 0] Generating ProjectContext...")
stage0 = controller.start_project(raw_idea=RAW_IDEA)
ctx: ProjectContext = stage0.draft_artifact
print(f"Project ID: {ctx.id}")
print(f"Title: {ctx.title}")
print(f"Keywords: {ctx.initial_keywords}\n")
approve(controller, ctx.id, "ProjectContext", ProjectContext)
# Out:
# 2025-11-21 10:38:57,939 - src.services.llm_provider - INFO - Using custom base URL: https://openrouter.ai/api/v1
# === FULL PIPELINE DEMO (Stages 0-3) ===
# 2025-11-21 10:38:58,408 - src.services.intelligent_model_service - INFO - IntelligentModelService initialized with provider: LLMProvider.OPENAI
# 2025-11-21 10:38:58,410 - src.services.intelligent_model_service - INFO - Generating project context from raw idea...
# 2025-11-21 10:38:58,412 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'timeout': 30, 'files': None, 'idempotency_key': 'stainless-python-retry-80fd244a-3788-495e-9cd1-797c7f8169db', 'json_data': {'messages': [{'role': 'system', 'content': 'You are an expert Research Methodologist with 20+ years of experience in systematic reviews and meta-analyses.\n\nYour role is to help researchers:\n- Frame research problems with academic rigor\n- Define clear, measurable research objectives\n- Establish appropriate scope boundaries\n- Identify key concepts and relationships\n\nYou ALWAYS output strictly valid JSON with no additional text.\nYou are precise, avoiding vague terms like "AI" when "Large Language Models" is meant.\nYou follow PICO framework (Population, Intervention, Comparison, Outcome) for clinical research.\n'}, {'role': 'user', 'content': 'Analyze this raw research idea and extract a structured project context.\n\nRaw idea:\n# Search Queries for Scoping Review\n\n**Research Topic:** Domain Shift and Generalization in Deep Learning-Based Crop Disease and Pest Detection\n\n**Research Question:** What is the landscape of research on domain shift and generalization  in deep learning-based crop disease and pest detection? What types of  evidence, methodologies, and gaps exist?\n\nReturn JSON with the following structure:\n{\n  "title": "Academic-style title (concise, descriptive)",\n  "discipline": "Primary academic field (e.g., Computer Science, Medicine, Psychology)",\n  "short_description": "2-3 sentence description of the research focus",\n  "initial_keywords": ["keyword1", "keyword2", "keyword3"],\n  "constraints": {\n    "time": "estimated timeline if mentioned",\n    "budget": "funding constraints if mentioned",\n    "access": "data/resource access constraints if mentioned"\n  }\n}\n\nBe specific. Avoid vague terms. Extract exact constraints from the text.\n'}], 'model': 'openai/gpt-4o-mini', 'max_tokens': None, 'temperature': 0.7}}
# 2025-11-21 10:38:58,413 - openai._base_client - DEBUG - Sending HTTP Request: POST https://openrouter.ai/api/v1/chat/completions
# 2025-11-21 10:38:58,414 - httpcore.connection - DEBUG - connect_tcp.started host='openrouter.ai' port=443 local_address=None timeout=30 socket_options=None
# 2025-11-21 10:38:58,427 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000223330C71E0>
# 2025-11-21 10:38:58,428 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x000002233197CC20> server_hostname='openrouter.ai' timeout=30
# 2025-11-21 10:38:58,447 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000022333104B90>
# 2025-11-21 10:38:58,448 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-11-21 10:38:58,449 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-11-21 10:38:58,450 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-11-21 10:38:58,451 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-11-21 10:38:58,452 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# [Stage 0] Generating ProjectContext...
# 2025-11-21 10:38:59,768 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 21 Nov 2025 18:39:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'gzip'), (b'Access-Control-Allow-Origin', b'*'), (b'Vary', b'Accept-Encoding'), (b'Permissions-Policy', b'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")'), (b'Referrer-Policy', b'no-referrer, strict-origin-when-cross-origin'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9a224ea5fb743369-AAE')])
# 2025-11-21 10:38:59,770 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-21 10:38:59,770 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-11-21 10:39:03,432 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-11-21 10:39:03,433 - httpcore.http11 - DEBUG - response_closed.started
# 2025-11-21 10:39:03,434 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-11-21 10:39:03,436 - openai._base_client - DEBUG - HTTP Response: POST https://openrouter.ai/api/v1/chat/completions "200 OK" Headers({'date': 'Fri, 21 Nov 2025 18:39:00 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'vary': 'Accept-Encoding', 'permissions-policy': 'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")', 'referrer-policy': 'no-referrer, strict-origin-when-cross-origin', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '9a224ea5fb743369-AAE'})
# 2025-11-21 10:39:03,437 - openai._base_client - DEBUG - request_id: None
# 2025-11-21 10:39:03,438 - src.services.intelligent_model_service - INFO - Project context generated: A Scoping Review on Domain Shift and Generalization in Deep Learning for Crop Disease and Pest Detection
# Project ID: project_9161c011
# Title: A Scoping Review on Domain Shift and Generalization in Deep Learning for Crop Disease and Pest Detection
# Keywords: ['domain shift', 'generalization', 'deep learning', 'crop disease detection', 'pest detection']

# %%
# Stage 1: Problem Framing + Concept Model
print("[Stage 1] Generating ProblemFraming & ConceptModel...")
stage1 = controller.run_stage("problem-framing", project_id=ctx.id)
framing: ProblemFraming = stage1.draft_artifact
concept_model: ConceptModel = stage1.extra_data.get("concept_model")
if framing is None:
    raise RuntimeError(f"Stage 1 failed: {stage1.validation_errors}")
print("Problem Statement:\n", framing.problem_statement)
print("Research Gap:\n", framing.research_gap)
print("Goals:", framing.goals)
print("Concepts:", [c.label for c in concept_model.concepts])
approve(controller, ctx.id, "ProblemFraming", ProblemFraming)
approve(controller, ctx.id, "ConceptModel", ConceptModel)
# Out:
# 2025-11-21 10:39:19,396 - src.services.intelligent_model_service - INFO - Generating problem framing for: A Scoping Review on Domain Shift and Generalization in Deep Learning for Crop Disease and Pest Detection
# 2025-11-21 10:39:19,397 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'timeout': 30, 'files': None, 'idempotency_key': 'stainless-python-retry-479f067b-8f5b-4929-8ea9-50a5d1adc7bc', 'json_data': {'messages': [{'role': 'system', 'content': 'You are a strict Senior Research Supervisor with expertise in research methodology.\n\nYour job is to find flaws in research framing:\n- Vague or undefined terms (e.g., "AI" instead of specific model types)\n- Overly broad scope that makes research infeasible\n- Missing operational definitions\n- Unclear or unmeasurable outcomes\n- Scope creep or conflicting objectives\n\nYou are NEVER satisfied with generic terms. You demand specificity.\nYou rate feasibility honestly - a score of 10 means "ready to execute", 1 means "needs complete redesign".\n\nOutput ONLY valid JSON with no extra text.\n'}, {'role': 'user', 'content': 'Critique this draft project context for research quality.\n\nTitle: A Scoping Review on Domain Shift and Generalization in Deep Learning for Crop Disease and Pest Detection\nDescription: This research aims to explore the current landscape of domain shift and generalization in deep learning methodologies applied to crop disease and pest detection. It will evaluate the types of evidence, methodologies employed, and identify existing research gaps in this domain.\n\nEvaluate on these dimensions:\n1. CLARITY: Are concepts clearly defined? Are there vague terms?\n2. SPECIFICITY: Is the scope narrow enough to be feasible?\n3. MEASURABILITY: Can outcomes be measured/evaluated?\n4. NOVELTY: Is there an implied research gap?\n\nReturn JSON with:\n{\n  "critique_summary": "2-3 paragraph detailed critique",\n  "feasibility_score": <integer 1-10>,\n  "specific_issues": [\n    "Issue 1: Vague term \'X\' should specify...",\n    "Issue 2: Scope too broad because...",\n    "Issue 3: Unclear how to measure..."\n  ]\n}\n\nBe harsh but constructive. A score of 10 means "publication-ready framing".\n'}], 'model': 'openai/gpt-4o-mini', 'max_tokens': None, 'temperature': 0.7}}
# 2025-11-21 10:39:19,400 - openai._base_client - DEBUG - Sending HTTP Request: POST https://openrouter.ai/api/v1/chat/completions
# 2025-11-21 10:39:19,402 - httpcore.connection - DEBUG - close.started
# 2025-11-21 10:39:19,404 - httpcore.connection - DEBUG - close.complete
# 2025-11-21 10:39:19,405 - httpcore.connection - DEBUG - connect_tcp.started host='openrouter.ai' port=443 local_address=None timeout=30 socket_options=None
# 2025-11-21 10:39:19,420 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000022333105910>
# 2025-11-21 10:39:19,421 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x000002233197CC20> server_hostname='openrouter.ai' timeout=30
# 2025-11-21 10:39:19,440 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002233310C9F0>
# 2025-11-21 10:39:19,441 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-11-21 10:39:19,442 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-11-21 10:39:19,443 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-11-21 10:39:19,444 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-11-21 10:39:19,446 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# [Stage 1] Generating ProblemFraming & ConceptModel...
# 2025-11-21 10:39:22,619 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 21 Nov 2025 18:39:23 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'gzip'), (b'Access-Control-Allow-Origin', b'*'), (b'Vary', b'Accept-Encoding'), (b'Permissions-Policy', b'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")'), (b'Referrer-Policy', b'no-referrer, strict-origin-when-cross-origin'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9a224f293d0a3351-AAE')])
# 2025-11-21 10:39:22,620 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-21 10:39:22,621 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-11-21 10:39:29,147 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-11-21 10:39:29,148 - httpcore.http11 - DEBUG - response_closed.started
# 2025-11-21 10:39:29,149 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-11-21 10:39:29,150 - openai._base_client - DEBUG - HTTP Response: POST https://openrouter.ai/api/v1/chat/completions "200 OK" Headers({'date': 'Fri, 21 Nov 2025 18:39:23 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'vary': 'Accept-Encoding', 'permissions-policy': 'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")', 'referrer-policy': 'no-referrer, strict-origin-when-cross-origin', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '9a224f293d0a3351-AAE'})
# 2025-11-21 10:39:29,151 - openai._base_client - DEBUG - request_id: None
# 2025-11-21 10:39:29,153 - src.services.intelligent_model_service - INFO - Critique complete. Feasibility score: 4/10
# 2025-11-21 10:39:29,154 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'timeout': 30, 'files': None, 'idempotency_key': 'stainless-python-retry-a4913894-b821-4c95-9c62-f518bdae7c95', 'json_data': {'messages': [{'role': 'system', 'content': 'You are an expert Research Methodologist with 20+ years of experience in systematic reviews and meta-analyses.\n\nYour role is to help researchers:\n- Frame research problems with academic rigor\n- Define clear, measurable research objectives\n- Establish appropriate scope boundaries\n- Identify key concepts and relationships\n\nYou ALWAYS output strictly valid JSON with no additional text.\nYou are precise, avoiding vague terms like "AI" when "Large Language Models" is meant.\nYou follow PICO framework (Population, Intervention, Comparison, Outcome) for clinical research.\n'}, {'role': 'user', 'content': 'Based on the critique below, refine the problem framing to address all issues.\n\nOriginal Context:\nThis research aims to explore the current landscape of domain shift and generalization in deep learning methodologies applied to crop disease and pest detection. It will evaluate the types of evidence, methodologies employed, and identify existing research gaps in this domain.\n\nCritique:\nThe title and description present a significant challenge in terms of clarity and specificity. The term \'domain shift\' is vague and lacks operational definition. It is unclear whether this refers to shifts in data distribution, changes in environmental conditions, or other factors, which undermines the clarity of the research focus. Furthermore, \'generalization\' in the context of deep learning should specify whether it pertains to model robustness, transferability across datasets, or performance on unseen data. This lack of precision compromises the overall coherence of the research objectives.\n\nThe scope of the study appears overly broad as it aims to encompass \'all methodologies\' employed in crop disease and pest detection without narrowing down to specific models or techniques, such as convolutional neural networks or transfer learning approaches. This breadth makes it challenging to conduct a thorough scoping review within a reasonable timeframe and resource allocation. Additionally, the description lacks measurable outcomes; it does not specify what constitutes \'evidence\' or \'research gaps\' and how these will be assessed. Without clear metrics, the evaluation of the findings will be subjective and difficult to validate. Although there is an implied gap in the integration of deep learning with agricultural practices, the lack of specificity could lead to conflicting objectives and scope creep.\n\nGenerate a refined problem framing that addresses all critique points.\n\nReturn JSON with:\n{\n  "problem_statement": "Clear 2-3 sentence statement of the problem",\n  "research_gap": "What is missing in current literature/practice",\n  "goals": [\n    "Specific goal 1 (use action verbs: evaluate, design, compare, etc.)",\n    "Specific goal 2",\n    "Specific goal 3"\n  ],\n  "scope_in": [\n    "What IS included (be specific about domains, methods, timeframes)",\n    "Include only what\'s essential"\n  ],\n  "scope_out": [\n    "What is explicitly EXCLUDED",\n    "State boundaries clearly"\n  ],\n  "key_concepts": [\n    {\n      "label": "Concept Name",\n      "type": "Population|Intervention|Outcome|Methodology|Context",\n      "description": "Brief description of this concept"\n    }\n  ]\n}\n\nMake goals SMART (Specific, Measurable, Achievable, Relevant, Time-bound).\nAddress EVERY issue from the critique.\n'}], 'model': 'openai/gpt-4o-mini', 'max_tokens': None, 'temperature': 0.7}}
# 2025-11-21 10:39:29,156 - openai._base_client - DEBUG - Sending HTTP Request: POST https://openrouter.ai/api/v1/chat/completions
# 2025-11-21 10:39:29,157 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-11-21 10:39:29,160 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-11-21 10:39:29,161 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-11-21 10:39:29,162 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-11-21 10:39:29,164 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-11-21 10:39:30,165 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 21 Nov 2025 18:39:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'gzip'), (b'Access-Control-Allow-Origin', b'*'), (b'Vary', b'Accept-Encoding'), (b'Permissions-Policy', b'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")'), (b'Referrer-Policy', b'no-referrer, strict-origin-when-cross-origin'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9a224f65ee463351-AAE')])
# 2025-11-21 10:39:30,166 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-21 10:39:30,167 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-11-21 10:39:40,158 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-11-21 10:39:40,158 - httpcore.http11 - DEBUG - response_closed.started
# 2025-11-21 10:39:40,159 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-11-21 10:39:40,160 - openai._base_client - DEBUG - HTTP Response: POST https://openrouter.ai/api/v1/chat/completions "200 OK" Headers({'date': 'Fri, 21 Nov 2025 18:39:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'vary': 'Accept-Encoding', 'permissions-policy': 'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")', 'referrer-policy': 'no-referrer, strict-origin-when-cross-origin', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '9a224f65ee463351-AAE'})
# 2025-11-21 10:39:40,161 - openai._base_client - DEBUG - request_id: None
# 2025-11-21 10:39:40,162 - src.services.validation_service - INFO - Validating 5 concepts...
# 2025-11-21 10:39:40,163 - src.services.validation_service - INFO - Validating term 'Domain Shift' against OpenAlex...
# 2025-11-21 10:39:40,167 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.openalex.org:443
# 2025-11-21 10:39:41,367 - urllib3.connectionpool - DEBUG - https://api.openalex.org:443 "GET /works?search=Domain+Shift&per_page=5 HTTP/1.1" 200 None
# 2025-11-21 10:39:41,717 - src.services.validation_service - INFO - Validation complete: Domain Shift -> 1415691 hits (ok)
# 2025-11-21 10:39:41,720 - src.services.validation_service - INFO - Validating term 'Generalization' against OpenAlex...
# 2025-11-21 10:39:41,723 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.openalex.org:443
# 2025-11-21 10:39:42,499 - urllib3.connectionpool - DEBUG - https://api.openalex.org:443 "GET /works?search=Generalization&per_page=5 HTTP/1.1" 200 None
# 2025-11-21 10:39:42,734 - src.services.validation_service - INFO - Validation complete: Generalization -> 1353713 hits (ok)
# 2025-11-21 10:39:42,736 - src.services.validation_service - INFO - Validating term 'Convolutional Neural Networks' against OpenAlex...
# 2025-11-21 10:39:42,739 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.openalex.org:443
# 2025-11-21 10:39:44,145 - urllib3.connectionpool - DEBUG - https://api.openalex.org:443 "GET /works?search=Convolutional+Neural+Networks&per_page=5 HTTP/1.1" 200 None
# 2025-11-21 10:39:44,531 - src.services.validation_service - INFO - Validation complete: Convolutional Neural Networks -> 614869 hits (ok)
# 2025-11-21 10:39:44,533 - src.services.validation_service - INFO - Validating term 'Transfer Learning' against OpenAlex...
# 2025-11-21 10:39:44,535 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.openalex.org:443
# 2025-11-21 10:39:45,759 - urllib3.connectionpool - DEBUG - https://api.openalex.org:443 "GET /works?search=Transfer+Learning&per_page=5 HTTP/1.1" 200 None
# 2025-11-21 10:39:45,964 - src.services.validation_service - INFO - Validation complete: Transfer Learning -> 1565663 hits (ok)
# 2025-11-21 10:39:45,967 - src.services.validation_service - INFO - Validating term 'Crop Disease and Pest Detection' against OpenAlex...
# 2025-11-21 10:39:45,970 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.openalex.org:443
# 2025-11-21 10:39:46,988 - urllib3.connectionpool - DEBUG - https://api.openalex.org:443 "GET /works?search=Crop+Disease+and+Pest+Detection&per_page=5 HTTP/1.1" 200 None
# 2025-11-21 10:39:47,268 - src.services.validation_service - INFO - Validation complete: Crop Disease and Pest Detection -> 57249 hits (ok)
# 2025-11-21 10:39:47,270 - src.services.validation_service - INFO - Validation complete: ✅ All 5 terms validated successfully in academic literature.
# 2025-11-21 10:39:47,270 - src.services.intelligent_model_service - INFO - Problem framing complete. 5 concepts extracted. Validation: ✅ All 5 terms validated successfully in academic literature.
# Problem Statement:
#  This research seeks to clarify the impact of data distribution shifts and environmental variability on the performance of convolutional neural networks (CNNs) for crop disease and pest detection. It aims to identify specific factors influencing model generalization, including robustness and transferability across diverse agricultural datasets.
# Research Gap:
#  Current literature lacks a comprehensive analysis of how domain shifts impact the generalization capabilities of specific deep learning methodologies in agricultural contexts, particularly regarding the effectiveness of CNNs and transfer learning techniques in varying environmental conditions.
# Goals: ['Evaluate the influence of data distribution shifts and environmental variability on the robustness of CNNs in crop disease detection by analyzing performance metrics such as accuracy and F1 score within a 6-month timeframe.', 'Compare the transferability of CNN models trained on one dataset to their performance on unseen datasets, focusing on agricultural environments with varied conditions over a 3-month period.', 'Identify and categorize evidence of existing research gaps in the integration of deep learning methodologies in agricultural pest detection, utilizing a systematic review approach to assess at least 50 relevant studies by the end of the research period.']
# Concepts: ['Domain Shift', 'Generalization', 'Convolutional Neural Networks', 'Transfer Learning', 'Crop Disease and Pest Detection']

# %%
# Stage 2: Research Questions
print("[Stage 2] Generating ResearchQuestionSet...")
stage2 = controller.run_stage("research-questions", project_id=ctx.id)
rq_set: ResearchQuestionSet = stage2.draft_artifact
if rq_set is None:
    raise RuntimeError(f"Stage 2 failed: {stage2.validation_errors}")
print(f"Generated {len(rq_set.questions)} research questions:")
for q in rq_set.questions:
    print(f" - ({q.priority}) [{q.type}] {q.text}")
approve(controller, ctx.id, "ResearchQuestionSet", ResearchQuestionSet)
# Out:
# 2025-11-21 10:40:29,582 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'timeout': 30, 'files': None, 'idempotency_key': 'stainless-python-retry-ae6176a8-5d60-4544-b270-c3d2f7f14e42', 'json_data': {'messages': [{'role': 'system', 'content': 'You are an expert Research Methodologist with 20+ years of experience in systematic reviews and meta-analyses.\n\nYour role is to help researchers:\n- Frame research problems with academic rigor\n- Define clear, measurable research objectives\n- Establish appropriate scope boundaries\n- Identify key concepts and relationships\n\nYou ALWAYS output strictly valid JSON with no additional text.\nYou are precise, avoiding vague terms like "AI" when "Large Language Models" is meant.\nYou follow PICO framework (Population, Intervention, Comparison, Outcome) for clinical research.\n'}, {'role': 'user', 'content': 'Based on the approved problem framing, generate structured research questions.\n\nProblem Statement: This research seeks to clarify the impact of data distribution shifts and environmental variability on the performance of convolutional neural networks (CNNs) for crop disease and pest detection. It aims to identify specific factors influencing model generalization, including robustness and transferability across diverse agricultural datasets.\nGoals: 1. Evaluate the influence of data distribution shifts and environmental variability on the robustness of CNNs in crop disease detection by analyzing performance metrics such as accuracy and F1 score within a 6-month timeframe.\n2. Compare the transferability of CNN models trained on one dataset to their performance on unseen datasets, focusing on agricultural environments with varied conditions over a 3-month period.\n3. Identify and categorize evidence of existing research gaps in the integration of deep learning methodologies in agricultural pest detection, utilizing a systematic review approach to assess at least 50 relevant studies by the end of the research period.\nKey Concepts: - Domain Shift (Methodology): Variability in data distribution due to changes in environmental conditions affecting crop disease and pest detection.\n- Generalization (Outcome): The ability of deep learning models, particularly CNNs, to maintain performance across diverse datasets and unseen scenarios.\n- Convolutional Neural Networks (Intervention): A class of deep learning algorithms applied specifically for image recognition tasks, such as detecting crop diseases and pests.\n- Transfer Learning (Intervention): A method in deep learning where a model developed for a specific task is reused as the starting point for a model on a second task.\n- Crop Disease and Pest Detection (Population): The application area focusing on identifying diseases and pests in crops using deep learning methodologies.\n\nGenerate 3-5 research questions using PICO framework where applicable.\n\nReturn JSON with:\n{\n  "questions": [\n    {\n      "text": "Research question text",\n      "type": "descriptive|explanatory|evaluative|design",\n      "linked_concepts": ["concept_id1", "concept_id2"],\n      "priority": "must_have|nice_to_have"\n    }\n  ]\n}\n'}], 'model': 'openai/gpt-4o-mini', 'max_tokens': None, 'temperature': 0.7}}
# 2025-11-21 10:40:29,584 - openai._base_client - DEBUG - Sending HTTP Request: POST https://openrouter.ai/api/v1/chat/completions
# 2025-11-21 10:40:29,585 - httpcore.connection - DEBUG - close.started
# 2025-11-21 10:40:29,586 - httpcore.connection - DEBUG - close.complete
# 2025-11-21 10:40:29,587 - httpcore.connection - DEBUG - connect_tcp.started host='openrouter.ai' port=443 local_address=None timeout=30 socket_options=None
# 2025-11-21 10:40:29,607 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002233310C5D0>
# 2025-11-21 10:40:29,608 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x000002233197CC20> server_hostname='openrouter.ai' timeout=30
# 2025-11-21 10:40:29,627 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000022333108F50>
# 2025-11-21 10:40:29,629 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-11-21 10:40:29,631 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-11-21 10:40:29,632 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-11-21 10:40:29,633 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-11-21 10:40:29,634 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# [Stage 2] Generating ResearchQuestionSet...
# 2025-11-21 10:40:30,721 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 21 Nov 2025 18:40:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'gzip'), (b'Access-Control-Allow-Origin', b'*'), (b'Vary', b'Accept-Encoding'), (b'Permissions-Policy', b'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")'), (b'Referrer-Policy', b'no-referrer, strict-origin-when-cross-origin'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9a2250dfef9db6be-AAE')])
# 2025-11-21 10:40:30,722 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-21 10:40:30,723 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-11-21 10:40:35,020 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-11-21 10:40:35,021 - httpcore.http11 - DEBUG - response_closed.started
# 2025-11-21 10:40:35,022 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-11-21 10:40:35,023 - openai._base_client - DEBUG - HTTP Response: POST https://openrouter.ai/api/v1/chat/completions "200 OK" Headers({'date': 'Fri, 21 Nov 2025 18:40:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'vary': 'Accept-Encoding', 'permissions-policy': 'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")', 'referrer-policy': 'no-referrer, strict-origin-when-cross-origin', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '9a2250dfef9db6be-AAE'})
# 2025-11-21 10:40:35,024 - openai._base_client - DEBUG - request_id: None
# Generated 5 research questions:
#  - (must_have) [explanatory] How do data distribution shifts affect the robustness of convolutional neural networks in detecting crop diseases and pests?
#  - (must_have) [evaluative] What is the impact of environmental variability on the performance metrics (accuracy and F1 score) of CNNs for crop disease detection?
#  - (must_have) [evaluative] To what extent do CNN models trained on one agricultural dataset transfer to unseen datasets with different environmental conditions?
#  - (nice_to_have) [descriptive] What research gaps exist in the application of deep learning methodologies for agricultural pest detection based on a systematic review of relevant studies?
#  - (nice_to_have) [explanatory] What factors influence the generalization of CNNs across diverse agricultural datasets in the context of crop disease and pest detection?

# %%
# Stage 3: Search Concept Expansion
print("[Stage 3] Generating SearchConceptBlocks...")
stage3 = controller.run_stage("search-concept-expansion", project_id=ctx.id)
blocks: SearchConceptBlocks = stage3.draft_artifact
if blocks is None:
    raise RuntimeError(f"Stage 3 failed: {stage3.validation_errors}")
print(f"Generated {len(blocks.blocks)} search concept blocks:")
for block in blocks.blocks:
    print(f" - {block.label}: {len(block.terms_included)} terms included")
    print(f"   Terms: {', '.join(block.terms_included[:6])}")
    if block.terms_excluded:
        print(f"   Excluded: {', '.join(block.terms_excluded)}")
approve(controller, ctx.id, "SearchConceptBlocks", SearchConceptBlocks)
# Out:
# 2025-11-21 10:41:54,100 - src.services.intelligent_model_service - DEBUG - Stage3 search expansion prompt:
# Based on the approved concepts and research questions, generate search concept blocks.
#
# Concepts:
# - Domain Shift (Methodology): Variability in data distribution due to changes in environmental conditions affecting crop disease and pest detection.
# - Generalization (Outcome): The ability of deep learning models, particularly CNNs, to maintain performance across diverse datasets and unseen scenarios.
# - Convolutional Neural Networks (Intervention): A class of deep learning algorithms applied specifically for image recognition tasks, such as detecting crop diseases and pests.
# - Transfer Learning (Intervention): A method in deep learning where a model developed for a specific task is reused as the starting point for a model on a second task.
# - Crop Disease and Pest Detection (Population): The application area focusing on identifying diseases and pests in crops using deep learning methodologies.
#
# Research Questions:
# - How do data distribution shifts affect the robustness of convolutional neural networks in detecting crop diseases and pests?
# - What is the impact of environmental variability on the performance metrics (accuracy and F1 score) of CNNs for crop disease detection?
# - To what extent do CNN models trained on one agricultural dataset transfer to unseen datasets with different environmental conditions?
# - What research gaps exist in the application of deep learning methodologies for agricultural pest detection based on a systematic review of relevant studies?
# - What factors influence the generalization of CNNs across diverse agricultural datasets in the context of crop disease and pest detection?
#
# For each major concept, create a search block with:
# - Synonyms and related terms
# - Narrower/broader terms
# - Common abbreviations
# - Terms to exclude (if applicable)
#
# Return JSON with:
# {
#   "blocks": [
#     {
#       "label": "Concept Label",
#       "description": "Brief description of this conceptual dimension",
#       "terms_included": ["primary term", "synonym1", "synonym2", "abbreviation"],
#       "terms_excluded": ["ambiguous term to exclude"]
#     }
#   ]
# }
#
# Include 3-8 blocks covering the main conceptual dimensions.
# Be specific with synonyms and avoid overly broad terms.
#
# 2025-11-21 10:41:54,103 - openai._base_client - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'timeout': 30, 'files': None, 'idempotency_key': 'stainless-python-retry-fe35aef8-f795-4c49-9568-1ab84f132991', 'json_data': {'messages': [{'role': 'system', 'content': 'You are an expert Research Librarian specializing in systematic literature searches.\n\nYour expertise includes:\n- Database-specific search syntax (PubMed, Scopus, Web of Science)\n- Boolean query construction\n- MeSH term identification\n- Search strategy optimization\n- Citation tracking\n\nYou help researchers construct comprehensive, reproducible search strategies.\nYou output strictly valid JSON.\n'}, {'role': 'user', 'content': 'Based on the approved concepts and research questions, generate search concept blocks.\n\nConcepts:\n- Domain Shift (Methodology): Variability in data distribution due to changes in environmental conditions affecting crop disease and pest detection.\n- Generalization (Outcome): The ability of deep learning models, particularly CNNs, to maintain performance across diverse datasets and unseen scenarios.\n- Convolutional Neural Networks (Intervention): A class of deep learning algorithms applied specifically for image recognition tasks, such as detecting crop diseases and pests.\n- Transfer Learning (Intervention): A method in deep learning where a model developed for a specific task is reused as the starting point for a model on a second task.\n- Crop Disease and Pest Detection (Population): The application area focusing on identifying diseases and pests in crops using deep learning methodologies.\n\nResearch Questions:\n- How do data distribution shifts affect the robustness of convolutional neural networks in detecting crop diseases and pests?\n- What is the impact of environmental variability on the performance metrics (accuracy and F1 score) of CNNs for crop disease detection?\n- To what extent do CNN models trained on one agricultural dataset transfer to unseen datasets with different environmental conditions?\n- What research gaps exist in the application of deep learning methodologies for agricultural pest detection based on a systematic review of relevant studies?\n- What factors influence the generalization of CNNs across diverse agricultural datasets in the context of crop disease and pest detection?\n\nFor each major concept, create a search block with:\n- Synonyms and related terms\n- Narrower/broader terms\n- Common abbreviations\n- Terms to exclude (if applicable)\n\nReturn JSON with:\n{\n  "blocks": [\n    {\n      "label": "Concept Label",\n      "description": "Brief description of this conceptual dimension",\n      "terms_included": ["primary term", "synonym1", "synonym2", "abbreviation"],\n      "terms_excluded": ["ambiguous term to exclude"]\n    }\n  ]\n}\n\nInclude 3-8 blocks covering the main conceptual dimensions.\nBe specific with synonyms and avoid overly broad terms.\n'}], 'model': 'openai/gpt-4o-mini', 'max_tokens': None, 'temperature': 0.7}}
# 2025-11-21 10:41:54,105 - openai._base_client - DEBUG - Sending HTTP Request: POST https://openrouter.ai/api/v1/chat/completions
# 2025-11-21 10:41:54,106 - httpcore.connection - DEBUG - close.started
# 2025-11-21 10:41:54,108 - httpcore.connection - DEBUG - close.complete
# 2025-11-21 10:41:54,109 - httpcore.connection - DEBUG - connect_tcp.started host='openrouter.ai' port=443 local_address=None timeout=30 socket_options=None
# 2025-11-21 10:41:54,165 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002233310A8F0>
# 2025-11-21 10:41:54,166 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x000002233197CC20> server_hostname='openrouter.ai' timeout=30
# 2025-11-21 10:41:54,182 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000002233309AA80>
# 2025-11-21 10:41:54,183 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-11-21 10:41:54,185 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-11-21 10:41:54,186 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-11-21 10:41:54,187 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-11-21 10:41:54,188 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# [Stage 3] Generating SearchConceptBlocks...
# 2025-11-21 10:41:55,076 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 21 Nov 2025 18:41:56 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'gzip'), (b'Access-Control-Allow-Origin', b'*'), (b'Vary', b'Accept-Encoding'), (b'Permissions-Policy', b'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")'), (b'Referrer-Policy', b'no-referrer, strict-origin-when-cross-origin'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9a2252f058c0b6c1-AAE')])
# 2025-11-21 10:41:55,077 - httpx - INFO - HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-21 10:41:55,078 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-11-21 10:42:04,643 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-11-21 10:42:04,644 - httpcore.http11 - DEBUG - response_closed.started
# 2025-11-21 10:42:04,644 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-11-21 10:42:04,645 - openai._base_client - DEBUG - HTTP Response: POST https://openrouter.ai/api/v1/chat/completions "200 OK" Headers({'date': 'Fri, 21 Nov 2025 18:41:56 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'gzip', 'access-control-allow-origin': '*', 'vary': 'Accept-Encoding', 'permissions-policy': 'payment=(self "https://checkout.stripe.com" "https://connect-js.stripe.com" "https://js.stripe.com" "https://*.js.stripe.com" "https://hooks.stripe.com")', 'referrer-policy': 'no-referrer, strict-origin-when-cross-origin', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '9a2252f058c0b6c1-AAE'})
# 2025-11-21 10:42:04,647 - openai._base_client - DEBUG - request_id: None
# 2025-11-21 10:42:04,648 - src.services.intelligent_model_service - DEBUG - Stage3 raw LLM response: ```json
# {
#   "blocks": [
#     {
#       "label": "Domain Shift (Methodology)",
#       "description": "Variability in data distribution due to changes in environmental conditions affecting crop disease and pest detection.",
#       "terms_included": ["domain shift", "data distribution shift", "environmental variability", "data drift"],
#       "terms_excluded": ["static data", "fixed distribution"]
#     },
#     {
#       "label": "Generalization (Outcome)",
#       "description": "The ability of deep learning models, particularly CNNs, to maintain performance across diverse datasets and unseen scenarios.",
#       "terms_included": ["generalization", "model robustness", "performance consistency", "transferable learning"],
#       "terms_excluded": ["overfitting", "specificity"]
#     },
#     {
#       "label": "Convolutional Neural Networks (Intervention)",
#       "description": "A class of deep learning algorithms applied specifically for image recognition tasks, such as detecting crop diseases and pests.",
#       "terms_included": ["CNN", "convolutional networks", "deep learning", "image recognition algorithms"],
#       "terms_excluded": ["recurrent neural networks", "traditional machine learning"]
#     },
#     {
#       "label": "Transfer Learning (Intervention)",
#       "description": "A method in deep learning where a model developed for a specific task is reused as the starting point for a model on a second task.",
#       "terms_included": ["transfer learning", "knowledge transfer", "fine-tuning", "pre-trained models"],
#       "terms_excluded": ["training from scratch", "non-transferable models"]
#     },
#     {
#       "label": "Crop Disease and Pest Detection (Population)",
#       "description": "The application area focusing on identifying diseases and pests in crops using deep learning methodologies.",
#       "terms_included": ["crop disease detection", "pest identification", "agricultural disease", "crop health monitoring"],
#       "terms_excluded": ["animal disease", "non-agricultural applications"]
#     }
#   ]
# }
# ```
# Generated 5 search concept blocks:
#  - Domain Shift (Methodology): 4 terms included
#    Terms: domain shift, data distribution shift, environmental variability, data drift
#    Excluded: static data, fixed distribution
#  - Generalization (Outcome): 4 terms included
#    Terms: generalization, model robustness, performance consistency, transferable learning
#    Excluded: overfitting, specificity
#  - Convolutional Neural Networks (Intervention): 4 terms included
#    Terms: CNN, convolutional networks, deep learning, image recognition algorithms
#    Excluded: recurrent neural networks, traditional machine learning
#  - Transfer Learning (Intervention): 4 terms included
#    Terms: transfer learning, knowledge transfer, fine-tuning, pre-trained models
#    Excluded: training from scratch, non-transferable models
#  - Crop Disease and Pest Detection (Population): 4 terms included
#    Terms: crop disease detection, pest identification, agricultural disease, crop health monitoring
#    Excluded: animal disease, non-agricultural applications

# %%
print(f"""### Final Summary
| Artifact | Status | Count |
|----------|--------|-------|
| ProjectContext | Approved | - |
| ProblemFraming | Approved | Goals: {len(framing.goals)} Concepts: {len(concept_model.concepts)} |
| ResearchQuestionSet | Approved | Questions: {len(rq_set.questions)} |
| SearchConceptBlocks | Approved | Blocks: {len(blocks.blocks)} |

Next Stage: Database Query Plan (Stage 4)
""")
# Out:
# ### Final Summary
# | Artifact | Status | Count |
# |----------|--------|-------|
# | ProjectContext | Approved | - |
# | ProblemFraming | Approved | Goals: 3 Concepts: 5 |
# | ResearchQuestionSet | Approved | Questions: 5 |
# | SearchConceptBlocks | Approved | Blocks: 5 |
#
# Next Stage: Database Query Plan (Stage 4)
